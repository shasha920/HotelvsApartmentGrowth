# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("InlandEmpireRevPARcorrelation.xlsx")
df.head()
# Out:
#    Period  Hotel RevPAR  US_Real_Interest _Rate_inflation_adjusted(%)  \
# 0    2000     51.032500                                      3.116589
# 1    2001     51.055833                                      2.237448
# 2    2002     50.736667                                      2.033603
# 3    2003     50.943333                                      1.445796
# 4    2004     55.013333                                      1.700858
#
#    US_Fixed_Rate_Mortgage_Average(%)  \
# 0                               8.05
# 1                               6.97
# 2                               6.54
# 3                               5.83
# 4                               5.84
#
#    US_Average_Pasenger_Fair_Current Dollars   US_Consumer_Spending ($)  \
# 0                                     339.00                  6767.179
# 1                                     320.62                  7073.801
# 2                                     312.33                  7348.941
# ...

# %%
correlation = df.corr()['Hotel RevPAR']
correlation
# Out:
# Period                                                     0.812599
# Hotel RevPAR                                               1.000000
# US_Real_Interest _Rate_inflation_adjusted(%)              -0.139692
# US_Fixed_Rate_Mortgage_Average(%)                         -0.118700
# US_Average_Pasenger_Fair_Current Dollars                   0.462738
# US_Consumer_Spending ($)                                   0.847930
# US_Personal_Saving_Rate(%)                                 0.015983
# US_10_Year_Treasury                                       -0.409243
# US_Unemployment_rate(%)                                   -0.622889
# 10-Year_Expected_Inflation                                -0.120466
# US_GDP (In Trillion)                                       0.900627
# CA_Crime_Rate (Rate per 100,000 population)               -0.237131
# CA_Population                                              0.666869
# CA_Median_Household_Income In Dollars 2000-2022(Charon)    0.915632
# ...

# %%
df1=pd.read_excel("InlandEmpireRevPAUcorrelation.xlsx")
df1.head()
# Out:
#    Period  aparment RevPAU  US_Real_Interest _Rate_inflation_adjusted(%)  \
# 0    2000        25.567850                                      3.116589
# 1    2001        27.693317                                      2.237448
# 2    2002        29.026658                                      2.033603
# 3    2003        30.423275                                      1.445796
# 4    2004        31.459533                                      1.700858
#
#    US_Fixed_Rate_Mortgage_Average(%)  \
# 0                               8.05
# 1                               6.97
# 2                               6.54
# 3                               5.83
# 4                               5.84
#
#    US_Average_Pasenger_Fair_Current Dollars   US_Consumer_Spending ($)  \
# 0                                     339.00                  6767.179
# 1                                     320.62                  7073.801
# 2                                     312.33                  7348.941
# ...

# %%
correlation = df1.corr()['aparment RevPAU']
correlation
# Out:
# Period                                                     0.887451
# aparment RevPAU                                            1.000000
# US_Real_Interest _Rate_inflation_adjusted(%)              -0.289700
# US_Fixed_Rate_Mortgage_Average(%)                         -0.216537
# US_Average_Pasenger_Fair_Current Dollars                   0.519953
# US_Consumer_Spending ($)                                   0.910074
# US_Personal_Saving_Rate(%)                                 0.070418
# US_10_Year_Treasury                                       -0.531821
# US_Unemployment_rate(%)                                   -0.412383
# 10-Year_Expected_Inflation                                -0.285606
# US_GDP (In Trillion)                                       0.961538
# CA_Crime_Rate (Rate per 100,000 population)               -0.377573
# CA_Population                                              0.740994
# CA_Median_Household_Income In Dollars 2000-2022(Charon)    0.963884
# ...

# %%
df2=pd.read_excel("CARevPAR.xlsx")
df2.head()
# Out:
#    Period   CARevPAR  US_Real_Interest _Rate_inflation_adjusted(%)  \
# 0  2000.0  71.000833                                      3.116589
# 1  2001.0  64.644167                                      2.237448
# 2  2002.0  59.872500                                      2.033603
# 3  2003.0  59.640000                                      1.445796
# 4  2004.0  64.203333                                      1.700858
#
#    US_Fixed_Rate_Mortgage_Average(%)  \
# 0                               8.05
# 1                               6.97
# 2                               6.54
# 3                               5.83
# 4                               5.84
#
#    US_Average_Pasenger_Fair_Current Dollars   US_Consumer_Spending ($)  \
# 0                                     339.00                  6767.179
# 1                                     320.62                  7073.801
# 2                                     312.33                  7348.941
# ...

# %%
correlation = df2.corr()['CARevPAR']
correlation
# Out:
# Period                                                     0.921670
# CARevPAR                                                   1.000000
# US_Real_Interest _Rate_inflation_adjusted(%)              -0.439220
# US_Fixed_Rate_Mortgage_Average(%)                         -0.458854
# US_Average_Pasenger_Fair_Current Dollars                   0.670667
# US_Consumer_Spending ($)                                   0.937372
# US_Personal_Saving_Rate(%)                                 0.299796
# US_10_Year_Treasury                                       -0.621844
# US_Unemployment_rate(%)                                   -0.437399
# 10-Year_Expected_Inflation                                -0.416411
# US_GDP (In Trillion)                                       0.915340
# CA_Crime_Rate (Rate per 100,000 population)               -0.556109
# CA_Population                                              0.878898
# CA_Median_Household_Income In Dollars 2000-2022(Charon)    0.928982
# ...

# %%
df3=pd.read_excel("CARevPAU.xlsx")
df3.head()
# Out:
#    Period   CARevPAU  US_Real_Interest _Rate_inflation_adjusted(%)  \
# 0    2000  39.048292                                      3.116589
# 1    2001  41.700633                                      2.237448
# 2    2002  41.062475                                      2.033603
# 3    2003  40.419817                                      1.445796
# 4    2004  40.413600                                      1.700858
#
#    US_Fixed_Rate_Mortgage_Average(%)  \
# 0                               8.05
# 1                               6.97
# 2                               6.54
# 3                               5.83
# 4                               5.84
#
#    US_Average_Pasenger_Fair_Current Dollars   US_Consumer_Spending ($)  \
# 0                                     339.00                  6767.179
# 1                                     320.62                  7073.801
# 2                                     312.33                  7348.941
# ...

# %%
correlation = df3.corr()['CARevPAU']
correlation
# Out:
# Period                                                     0.942134
# CARevPAU                                                   1.000000
# US_Real_Interest _Rate_inflation_adjusted(%)              -0.386662
# US_Fixed_Rate_Mortgage_Average(%)                         -0.332017
# US_Average_Pasenger_Fair_Current Dollars                   0.616647
# US_Consumer_Spending ($)                                   0.959193
# US_Personal_Saving_Rate(%)                                 0.223826
# US_10_Year_Treasury                                       -0.605235
# US_Unemployment_rate(%)                                   -0.403941
# 10-Year_Expected_Inflation                                -0.376879
# US_GDP (In Trillion)                                       0.981573
# CA_Crime_Rate (Rate per 100,000 population)               -0.479287
# CA_Population                                              0.829411
# CA_Median_Household_Income In Dollars 2000-2022(Charon)    0.989234
# ...
